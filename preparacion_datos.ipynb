# %%
#importo librerias
import pandas as pd
import json
import ast

# %%
#creo listas que contendran los datos
lista_reviews = []
lista_items = []
lista_games = []

# %%
#leo los json
with open("PI MLOps - STEAM/australian_user_reviews.json", 'r', encoding="utf-8")as file:
    for linea in file.readlines():
        lista_reviews.append(ast.literal_eval(linea))

with open("PI MLOps - STEAM/output_steam_games.json", 'r', encoding="utf-8")as file:
    for linea in file.readlines():
        lista_games.append(json.loads(linea))

# %%
with open("PI MLOps - STEAM/australian_users_items.json", 'r', encoding="utf-8")as file:
    for linea in file.readlines():
        lista_items.append(ast.literal_eval(linea))

# %%
#creo los dataframe
df_reviews = pd.DataFrame(lista_reviews)
df_items = pd.DataFrame(lista_items)
df_games = pd.DataFrame(lista_games)

# %%
df_reviews.head()
df_reviews.describe()

# %%
df_items.head()
df_items.describe()

# %%
df_games.head()
df_games.describe()

# %%
df_games.rename(columns={"id":"item_id"})
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
#modifico el tipo de dato de price
df_games['price'] = df_games['price'].astype(str)

#transformo a parquet
df_reviews.to_parquet("PI MLOps - STEAM/australian_user_reviews.parquet",engine="pyarrow")
df_items.to_parquet("PI MLOps - STEAM/australian_users_items.parquet",engine="pyarrow")
df_games.to_parquet("PI MLOps - STEAM/output_steam_games.parquet",engine="pyarrow")
